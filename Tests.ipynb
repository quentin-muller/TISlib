# %% [markdown]
# # Tests

# %% [markdown]
# ## imgLevelAdjust

# %%
import TIS
import numpy as np

f = np.array([[-128,1,2,3],[100,35,50,80]], dtype='int8')

TIS.showImage(f)


h = TIS.computeHisto(f)

# %%
_ = TIS.showHistogram(f)

# %%
print(f)

g = TIS.imgLevelAdjust(f)

print(g)
# Out:
# [[-128    1    2    3]
#  [ 100   35   50   80]]
# [[  0 255 255 255]
#  [255 255 255 255]]

# %%
A = np.array([[1,2,3,31,123,13,1,1,1],[4,5,6,1,2,3,4,1,2]], dtype='uint8')
B = np.array([[25,100,8],[99,200,12]], dtype='uint8')

C = [A,B,B,A]
TIS.showImage(C, width=15)
# Out:
# (<Figure size 1080x720 with 8 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AE6B6ACBE0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001AE6B8FF1C0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000001AE6BAAA640>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001AE6BAD6A60>]],
#        dtype=object))
